# %% [markdown]
# # Exploratory Data Analysis Through a Geometric Lens
# #
# # **Primary Question**: What geometric properties emerge when we view pollutants as points in ℝⁿ?
# #
# # ## Key Geometric Hypotheses to Test:
# # 1. Do pollutants form distinct clusters in high-dimensional space?
# # 2. Is there a "manifold" of normal operation vs. pollution events?
# # 3. Which distance metric (Euclidean vs. Cosine) best captures meaningful similarity?

# %%
# Imports.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# Plotting settings.
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (12, 6)

# Loading data using project loader
from src.data_loader import load_processed_data
df = load_processed_data()

# Dropping unnamed empty columns.
df.dropna(axis=1, how='all', inplace=True)

# Previewing the data.
print("Shape of data:", df.shape)
display(df.head())

# Column information.
print("\nColumn info:")
df.info()

# Checking for nulls and missing values.
print("\nMissing values per column:")
print(df.isnull().sum())

# Replacing -200 with NaN (as per dataset documentation)
df.replace(-200, np.nan, inplace=True)

# Converting Date and Time columns to datetime.
if 'Date' in df.columns and 'Time' in df.columns:
    df['Datetime'] = pd.to_datetime(df['Date'].astype(str) + ' ' + df['Time'].astype(str), errors='coerce')
    df.drop(columns=['Date', 'Time'], inplace=True)
    df.set_index('Datetime', inplace=True)

# Convert pollutant columns to numeric (in case some are still strings)
pollutants = ['CO(GT)', 'NO2(GT)', 'C6H6(GT)']
for col in pollutants:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Display cleaned sample
print("\nCleaned sample:")
display(df[pollutants].dropna().head())

# Summary statistics
display(df.describe())

# Plotting missing data heatmap.
plt.figure(figsize=(12, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title("Missing Values Heatmap")
plt.show()

# Correlation heatmap of numeric variables
plt.figure(figsize=(14, 10))
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# Line plot of key pollutants (e.g., CO(GT), NO2(GT), C6H6(GT))
df_plot = df[pollutants].dropna().sort_index()

# Ensure there's data to plot
if df_plot.empty:
    print("No valid data to plot after cleaning.")
else:
    df_plot.plot(subplots=True, layout=(3, 1), figsize=(14, 10), legend=True, title='Pollutant Concentrations Over Time')
    plt.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 14
#      11 plt.rcParams["figure.figsize"] = (12, 6)
#      13 # Loading data using project loader
# ---> 14 from src.data_loader import load_processed_data
#      15 df = load_processed_data()
#      17 # Dropping unnamed empty columns.
#
# ModuleNotFoundError: No module named 'src'
