# %%
# Air Quality Analysis: Exploratory Data Analysis
#
# **Technical Spine Focus**: Understanding the geometric properties of multivariate time-series data.

# Setup.
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Environment ready")

# First, let's check where we are and where the data is
print(f"Current directory: {os.getcwd()}")
print(f"Does 'data' directory exist? {os.path.exists('data')}")

# Function to load data directly (no module import needed)
def load_air_quality_data():
    """Load the Air Quality dataset with proper formatting"""

    # Try multiple possible locations
    possible_paths = [
        '../data/raw/AirQualityUCI.csv',  # From notebooks/ directory
        'data/raw/AirQualityUCI.csv',     # From project root
        './data/raw/AirQualityUCI.csv',   # Current directory with data subfolder
        'AirQualityUCI.csv',              # Directly in current directory
    ]

    filepath = None
    for path in possible_paths:
        if os.path.exists(path):
            filepath = path
            print(f"Found file at: {os.path.abspath(filepath)}")
            break

    if filepath is None:
        # List what's available to help debug
        print("\nAvailable files in current directory:")
        for item in os.listdir('.'):
            print(f"  {item}")
        if os.path.exists('..'):
            print("\nAvailable in parent directory:")
            for item in os.listdir('..'):
                print(f"  {item}")
        raise FileNotFoundError("Could not find AirQualityUCI.csv")

    # Read with European settings
    df = pd.read_csv(
        filepath,
        sep=';',
        decimal=',',
        na_values=[-200, -200.0],
        low_memory=False
    )

    # Check what columns we have
    print(f"\nOriginal columns: {df.columns.tolist()}")
    print(f"Original shape: {df.shape}")

    # Clean column names (remove extra spaces)
    df.columns = df.columns.str.strip()

    # Check for Date and Time columns (they might have different names)
    date_col = None
    time_col = None

    # Try different possible column names
    for col in df.columns:
        if 'date' in col.lower():
            date_col = col
        elif 'time' in col.lower():
            time_col = col

    # If not found, use the first two columns (common in this dataset)
    if date_col is None and len(df.columns) >= 2:
        date_col = df.columns[0]
        time_col = df.columns[1]
        print(f"Using {date_col} as date and {time_col} as time")

    if date_col is None or time_col is None:
        raise ValueError(f"Cannot find date/time columns. Available: {df.columns.tolist()}")

    print(f"Date column: {date_col}, Time column: {time_col}")

    # Merge date and time
    try:
        df['datetime'] = pd.to_datetime(
            df[date_col].astype(str) + ' ' + df[time_col].astype(str),
            format='%d/%m/%Y %H.%M.%S',
            errors='coerce'
        )
    except:
        # Try alternative format
        df['datetime'] = pd.to_datetime(
            df[date_col].astype(str) + ' ' + df[time_col].astype(str),
            errors='coerce'
        )

    # Check for successful parsing
    print(f"Datetime parsing successful: {df['datetime'].notna().sum()}/{len(df)} rows")

    # Set datetime as index
    df.set_index('datetime', inplace=True)

    # Drop original date/time columns
    df.drop([date_col, time_col], axis=1, inplace=True, errors='ignore')

    # Drop any completely empty columns
    df.dropna(axis=1, how='all', inplace=True)

    # Ensure numeric data types
    for col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')

    # Sort by datetime
    df.sort_index(inplace=True)

    print(f"Final shape: {df.shape}")
    print(f"Date range: {df.index.min()} to {df.index.max()}")

    return df

# Loading raw data.
print("\n" + "="*50)
print("Loading data...")
print("="*50)

try:
    df_raw = load_air_quality_data()
    print("Data loaded successfully!")

    # Initial statistics.
    print("\n" + "="*50)
    print("Basic Statistics:")
    print("="*50)
    print(df_raw.describe())

    # Missing values analysis.
    print("\n" + "="*50)
    print("Missing Values Analysis:")
    print("="*50)

    missing = df_raw.isnull().sum()
    missing_pct = (missing / len(df_raw)) * 100

    missing_df = pd.DataFrame({
        'Missing Count': missing,
        'Missing %': missing_pct
    })
    missing_df = missing_df[missing_df['Missing Count'] > 0]

    if len(missing_df) > 0:
        print(missing_df.sort_values('Missing %', ascending=False))
    else:
        print("No missing values!")

    # Create outputs directory if it doesn't exist
    os.makedirs('../outputs/figures', exist_ok=True)
    os.makedirs('outputs/figures', exist_ok=True)

    # Visualization: Time series of key pollutants
    print("\n" + "="*50)
    print("Creating visualizations...")
    print("="*50)

    # Identify pollutant columns (based on common names in this dataset)
    pollutant_keywords = ['CO', 'NMHC', 'C6H6', 'NOx', 'NO2', 'PT08']
    pollutant_cols = []

    for col in df_raw.columns:
        for keyword in pollutant_keywords:
            if keyword in col:
                pollutant_cols.append(col)
                break

    print(f"Found pollutant columns: {pollutant_cols}")

    if len(pollutant_cols) > 0:
        # Take up to 6 pollutants for plotting
        pollutants = pollutant_cols[:6]

        fig, axes = plt.subplots(3, 2, figsize=(15, 12))
        axes = axes.flatten()

        for idx, col in enumerate(pollutants):
            if idx < len(axes):
                # Check if we have data for this column
                if col in df_raw.columns and df_raw[col].notna().sum() > 0:
                    # Resample to daily for cleaner plot
                    daily_data = df_raw[col].resample('D').mean()
                    axes[idx].plot(daily_data.index, daily_data.values, linewidth=1)
                    axes[idx].set_title(col, fontweight='bold')
                    axes[idx].set_ylabel('Concentration')
                    axes[idx].grid(True, alpha=0.3)
                    axes[idx].tick_params(axis='x', rotation=45)
                else:
                    axes[idx].text(0.5, 0.5, f'No data for {col}',
                                 ha='center', va='center', transform=axes[idx].transAxes)
                    axes[idx].set_title(col, fontweight='bold')

        # Turn off any unused subplots
        for idx in range(len(pollutants), len(axes)):
            axes[idx].axis('off')

        plt.suptitle('Daily Average Pollutant Concentrations', fontsize=16, fontweight='bold')
        plt.tight_layout()

        # Try multiple save locations
        try:
            plt.savefig('../outputs/figures/01_pollutant_time_series.png', dpi=150, bbox_inches='tight')
            print("Saved figure to ../outputs/figures/01_pollutant_time_series.png")
        except:
            try:
                plt.savefig('outputs/figures/01_pollutant_time_series.png', dpi=150, bbox_inches='tight')
                print("Saved figure to outputs/figures/01_pollutant_time_series.png")
            except:
                print("Could not save figure - showing only")

        plt.show()

        # Geometric insight: Correlation as distance preview
        print("\n" + "="*50)
        print("Correlation Matrix:")
        print("="*50)

        # Use only columns with enough non-null data
        valid_cols = []
        for col in pollutants:
            if col in df_raw.columns and df_raw[col].notna().sum() > 10:
                valid_cols.append(col)

        if len(valid_cols) >= 2:
            corr_matrix = df_raw[valid_cols].corr()
            print(corr_matrix.round(2))

            plt.figure(figsize=(10, 8))
            sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', center=0,
                       square=True, linewidths=1, cbar_kws={'label': 'Correlation'})
            plt.title('Pollutant Correlation Matrix', fontsize=14, fontweight='bold')
            plt.tight_layout()

            # Try multiple save locations
            try:
                plt.savefig('../outputs/figures/01_correlation_matrix.png', dpi=150, bbox_inches='tight')
                print("Saved figure to ../outputs/figures/01_correlation_matrix.png")
            except:
                try:
                    plt.savefig('outputs/figures/01_correlation_matrix.png', dpi=150, bbox_inches='tight')
                    print("Saved figure to outputs/figures/01_correlation_matrix.png")
                except:
                    print("Could not save correlation matrix - showing only")

            plt.show()
        else:
            print("Not enough data for correlation matrix (need at least 2 valid columns)")
    else:
        print("No pollutant columns found for visualization")
        print(f"Available columns: {df_raw.columns.tolist()}")

    # Hypothesis generation
    print("\n" + "="*50)
    print("HYPOTHESES FOR GEOMETRIC ANALYSIS:")
    print("="*50)
    print("1. CO(GT) and PT08.S1(CO) should be geometrically close (high correlation).")
    print("2. Different times of day may form clusters in feature space.")
    print("3. Weekends may have different pollution geometry than weekdays.")
    print("4. The -200 missing values may indicate sensor failure regimes.")
    print("\nThese will be tested in subsequent analyses.")

except Exception as e:
    print(f"\nERROR: {e}")
    print("\nTroubleshooting tips:")
    print("1. Make sure the AirQualityUCI.csv file is in the correct location")
    print("2. Try placing it in the same directory as your notebook")
    print("3. Or create a 'data/raw' folder in your current directory")
    print("\nYou can download the dataset from:")
    print("https://archive.ics.uci.edu/ml/machine-learning-databases/00360/AirQualityUCI.zip")
# Out:
# Environment ready
# Current directory: c:\Users\nate\Documents\GitHub\Air-Quality-Analysis\notebooks
# Does 'data' directory exist? False
#
# ...
# Loading data...
# ...
# Found file at: c:\Users\nate\Documents\GitHub\Air-Quality-Analysis\data\raw\AirQualityUCI.csv
#
# Original columns: ['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)', 'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)', 'PT08.S5(O3)', 'T', 'RH', 'AH', 'Unnamed: 15', 'Unnamed: 16']
# Original shape: (9471, 17)
# Date column: Date, Time column: Time
# Datetime parsing successful: 9357/9471 rows
# Final shape: (9471, 13)
# Date range: 2004-03-10 18:00:00 to 2005-04-04 14:00:00
# Data loaded successfully!
#
# ...
# Basic Statistics:
# ...
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  7674.000000  8991.000000   914.000000  8991.000000    8991.000000
# mean      2.152750  1099.833166   218.811816    10.083105     939.153376
# ...
