# %%
# %% [markdown]
# # Air Quality Analysis: Phase 1 - Exploratory Data Analysis
#
# **Technical Spine Focus**: Understanding the geometric properties of multivariate time-series data.

# %%
# Setup
import sys
sys.path.append('../src')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from data_loader import load_raw_data

print(" Environment ready")

# %%
# Load raw data
df_raw = load_raw_data()
print(f" Raw data shape: {df_raw.shape}")
print(f" Date range: {df_raw.index.min()} to {df_raw.index.max()}")
print("\nColumns:")
for col in df_raw.columns:
    print(f"  • {col}")

# %%
# Initial statistics
print(" Basic Statistics:")
print(df_raw.describe())

# %%
# Missing values analysis
missing = df_raw.isnull().sum()
missing_pct = (missing / len(df_raw)) * 100

print(" Missing Values Analysis:")
for col in df_raw.columns:
    if missing[col] > 0:
        print(f"  {col}: {missing[col]} missing ({missing_pct[col]:.1f}%)")

# %%
# Visualization: Time series of key pollutants
fig, axes = plt.subplots(3, 2, figsize=(15, 12))
pollutants = ['CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)', 'NOx(GT)', 'NO2(GT)']

for idx, ax in enumerate(axes.flatten()):
    if idx < len(pollutants) and pollutants[idx] in df_raw.columns:
        # Resample to daily for cleaner plot
        df_raw[pollutants[idx]].resample('D').mean().plot(ax=ax, linewidth=1)
        ax.set_title(pollutants[idx], fontweight='bold')
        ax.set_ylabel('Concentration')
        ax.grid(True, alpha=0.3)
    else:
        ax.axis('off')

plt.suptitle('Daily Average Pollutant Concentrations', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.savefig('../outputs/figures/01_pollutant_time_series.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# Geometric insight: Correlation as distance preview
print(" Correlation Matrix (Preview of Relationships):")

corr_cols = [col for col in pollutants if col in df_raw.columns]
corr_matrix = df_raw[corr_cols].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', center=0,
           square=True, linewidths=1, cbar_kws={'label': 'Correlation'})
plt.title('Pollutant Correlation Matrix', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig('../outputs/figures/01_correlation_matrix.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# Hypothesis generation
print("\n HYPOTHESES FOR GEOMETRIC ANALYSIS:")
print("=" * 50)
print("1. CO(GT) and PT08.S1(CO) should be geometrically close (high correlation).")
print("2. Different times of day may form clusters in feature space.")
print("3. Weekends may have different pollution geometry than weekdays.")
print("4. The -200 missing values may indicate sensor failure regimes.")
print("\nThese will be tested in subsequent analyses.")
# Out:
#  Environment ready
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 21
#      17 print(" Environment ready")
#      19 # %%
#      20 # Load raw data
# ---> 21 df_raw = load_raw_data()
#      22 print(f" Raw data shape: {df_raw.shape}")
#      23 print(f" Date range: {df_raw.index.min()} to {df_raw.index.max()}")
#
# File c:\Users\nate\Documents\GitHub\Air-Quality-Analysis\notebooks\../src\data_loader.py:27, in load_raw_data(filepath)
#      13 """
#      14 Load the raw UCI Air Quality dataset with correct European formatting.
#      15
#    (...)     24     Raw DataFrame with proper parsing
#      25 """
#      26 # Read with European settings
# ---> 27 df = pd.read_csv(
#      28     filepath,
#      29     sep=';',
#      30     decimal=',',
#      31     na_values=[-200, -200.0]
#      32 )
#      34 # Merge date and time
# ...
